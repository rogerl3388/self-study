# %%
import numpy as np
import pandas as pd

# %%
A = np.array([
    ['a', 'b', 'c'],
    ['d', 'e', 'f'],
    ['g', 'h', 'i']
])

print(A[:, :2])
print("\n")
print("3")
# Out:
# [['a' 'b']
#  ['d' 'e']
#  ['g' 'h']]
#
#
# 3
